# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import os
import psycopg2

from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sqlalchemy import create_engine
from dotenv import load_dotenv
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score

# %% [markdown]
# # Load dataset

# %%
env_path = os.path.abspath("../.env")
load_dotenv(dotenv_path=env_path)

DB_USER = os.getenv("DB_USER")
DB_PASSWORD = os.getenv("DB_PASSWORD")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

engine = create_engine(
    f"postgresql+psycopg2://{DB_USER}:{DB_PASSWORD}@{DB_HOST}:{DB_PORT}/{DB_NAME}"
)


df = pd.read_sql("SELECT * FROM feature.training_fraud_dataset", engine)
df
# Out:
#            event_hour  tx_count  total_tx_amount  avg_tx_amount  \
# 0 2025-12-25 01:00:00       464     2.349727e+08  506406.724138
# 1 2025-12-24 23:00:00      5568     2.819673e+09  506406.724138
#
#    max_tx_amount  std_tx_amount  avg_account_balance  risky_tx_count  \
# 0      4963146.0   1.040360e+06        575492.148707             408
# 1      4963146.0   1.039332e+06        575492.148707            4896
#
#    active_users  total_clicks  total_impressions  conversion_rate  \
# 0       41188.0    10638243.0           105754.0         0.172963
# 1           NaN           NaN                NaN              NaN
#
#    avg_clicks_per_user  avg_tx_per_event    ctr  fraud_label  \
# 0            258.28501     506406.724138  100.0            0
# 1                  NaN     506406.724138    NaN            0
#
#          fraud_reason
# 0  HIGH_TX_VS_BALANCE
# 1  HIGH_TX_VS_BALANCE
